# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS*43
print("thickness: {} Meters".format(folded_thickness))
# Out:
# thickness: 0.0034400000000000003 Meters

# %%
THICKNESS = 1000
folded_thickness = THICKNESS*1000
print ("Thickness: {:.2f}km". format(folded_thickness/1000))
# Out:
# Thickness: 1000.00km

# %%
THICKNESS = 1000
folded_thickness = THICKNESS*100+200*800+600/2-100-700/300
print("thickness:{: .2f}km". format (folded_thickness/1000))
# Out:
# thickness: 260.20km

# %%
# %%timeit 
import time
start = time.time()
#####
#THICKNES = 1000
folded_thickness = THICKNESS*1000
print("thickness: {:.2f}km". format (folded_thickness/1000))
#####
elapsed_time =time.time() - start
print ("time : {}[s]". format(elapsed_time))
# Out:
# thickness: 1000.00km
# time : 0.004033327102661133[s]
# thickness: 1000.00km
# time : 0.0010018348693847656[s]
# thickness: 1000.00km
# time : 0.0020024776458740234[s]
# thickness: 1000.00km
# time : 0.0019998550415039062[s]
# thickness: 1000.00km
# time : 0.0010287761688232422[s]
# thickness: 1000.00km
# time : 0.00099945068359375[s]
# thickness: 1000.00km
# time : 0.0010042190551757812[s]
# thickness: 1000.00km
# time : 0.002002239227294922[s]
# thickness: 1000.00km
# time : 0.0010318756103515625[s]
# thickness: 1000.00km
# time : 0.001996755599975586[s]
# thickness: 1000.00km
# time : 0.0020294189453125[s]
# thickness: 1000.00km
# time : 0.001999378204345703[s]
# thickness: 1000.00km
# time : 0.0019719600677490234[s]
# thickness: 1000.00km
# time : 0.002000570297241211[s]
# thickness: 1000.00km
# time : 0.033965349197387695[s]
# thickness: 1000.00km
# time : 0.001032114028930664[s]
# thickness: 1000.00km
# time : 0.0010018348693847656[s]
# thickness: 1000.00km
# time : 0.0020303726196289062[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009715557098388672[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.001027822494506836[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.000997781753540039[s]
# thickness: 1000.00km
# time : 0.0010037422180175781[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009732246398925781[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010268688201904297[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010006427764892578[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010027885437011719[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.00099945068359375[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.004998207092285156[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009975433349609375[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010023117065429688[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.03400707244873047[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009996891021728516[s]
# thickness: 1000.00km
# time : 0.0009675025939941406[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.001995086669921875[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009663105010986328[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010280609130859375[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010004043579101562[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.000997781753540039[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010097026824951172[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009946823120117188[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010013580322265625[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009975433349609375[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009970664978027344[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010037422180175781[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.000997781753540039[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009958744049072266[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010044574737548828[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009672641754150391[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009927749633789062[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010259151458740234[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.07297134399414062[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.001001119613647461[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.000997781753540039[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010018348693847656[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.000990152359008789[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.001001119613647461[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.001001596450805664[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009980201721191406[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010051727294921875[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009963512420654297[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010039806365966797[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010030269622802734[s]
# thickness: 1000.00km
# time : 0.0009999275207519531[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010001659393310547[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010025501251220703[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009982585906982422[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010063648223876953[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.001003265380859375[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009930133819580078[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009953975677490234[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010068416595458984[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010018348693847656[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010004043579101562[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010030269622802734[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009953975677490234[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010068416595458984[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.20689105987548828[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.01556396484375[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.015542745590209961[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.015659570693969727[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.015589475631713867[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.01564168930053711[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.004359722137451172[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009918212890625[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0019986629486083984[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009958744049072266[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009429454803466797[s]
# thickness: 1000.00km
# time : 0.002061128616333008[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009958744049072266[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009968280792236328[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009381771087646484[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010585784912109375[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009999275207519531[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009999275207519531[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010001659393310547[s]
# thickness: 1000.00km
# time : 0.0009989738464355469[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010688304901123047[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010051727294921875[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009992122650146484[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010006427764892578[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010609626770019531[s]
# thickness: 1000.00km
# time : 0.0010030269622802734[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010044574737548828[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009982585906982422[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010020732879638672[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009992122650146484[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010020732879638672[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010051727294921875[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009996891021728516[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009984970092773438[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010073184967041016[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009999275207519531[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009958744049072266[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.000997781753540039[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009992122650146484[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009968280792236328[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# ...
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.008524894714355469[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010006427764892578[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009953975677490234[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.001001119613647461[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009992122650146484[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.007821321487426758[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009348392486572266[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010023117065429688[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.002999544143676758[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010001659393310547[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009930133819580078[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.003007650375366211[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009982585906982422[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.002074003219604492[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010008811950683594[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.004990577697753906[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0009999275207519531[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010051727294921875[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010051727294921875[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0010006427764892578[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# thickness: 1000.00km
# time : 0.0[s]
# 1.16 ms ± 218 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
start = time.time()
#####
#THICKNESS =0000
folded_thickness = THICKNESS*2
print("thickness: {:.2f}km". format (folded_thickness/1000))
#####
# Out:
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# ...
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# thickness: 0.00km
# 639 µs ± 149 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS*44
print("thickness: {} Meters".format(folded_thickness*44))
# Out:
# thickness: 0.15488000000000002 Meters

# %%
""
Matplolotlib X
""
import matplotlib.pyblot as plt
# %matplotlib inline
plt.title("thickness of folded paper")
plt.xlabel("")
